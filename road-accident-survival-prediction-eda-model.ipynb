# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/kaggle/input/road-accident-survival-dataset/accident.csv')
data.head()
# Out:
#    Age  Gender  Speed_of_Impact Helmet_Used Seatbelt_Used  Survived
# 0   56  Female             27.0          No            No         1
# 1   69  Female             46.0          No           Yes         1
# 2   46    Male             46.0         Yes           Yes         0
# 3   32    Male            117.0          No           Yes         0
# 4   60  Female             40.0         Yes           Yes         0

# %%
data.shape # Total Rows and Columns
# Out:
# (200, 6)

# %%
data.isnull().sum() # this code shows null values Datset
# Out:
# Age                0
# Gender             1
# Speed_of_Impact    3
# Helmet_Used        0
# Seatbelt_Used      0
# Survived           0
# dtype: int64

# %%
data = data.dropna()

# %%
data.duplicated().sum() # this code shows duplicated values in Dataset
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 196 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Age              196 non-null    int64
#  1   Gender           196 non-null    object
#  2   Speed_of_Impact  196 non-null    float64
#  3   Helmet_Used      196 non-null    object
#  4   Seatbelt_Used    196 non-null    object
#  5   Survived         196 non-null    int64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 10.7+ KB

# %%
data.describe()
# Out:
#               Age  Speed_of_Impact    Survived
# count  196.000000       196.000000  196.000000
# mean    43.341837        70.433673    0.510204
# std     15.004973        30.202236    0.501176
# min     18.000000        20.000000    0.000000
# 25%     31.000000        43.000000    0.000000
# 50%     44.000000        71.000000    1.000000
# 75%     56.000000        95.500000    1.000000
# max     69.000000       119.000000    1.000000

# %%
print(data['Survived'].value_counts())
print('\n')
print(data['Helmet_Used'].value_counts())
print('\n')
print(data['Seatbelt_Used'].value_counts())
# Out:
# Survived
# 1    100
# 0     96
# Name: count, dtype: int64
#
#
# Helmet_Used
# Yes    109
# No      87
# Name: count, dtype: int64
#
#
# Seatbelt_Used
# Yes    110
# No      86
# Name: count, dtype: int64

# %% [markdown]
# # EDA

# %%
plt.figure(figsize=(10, 6))
count = data['Survived'].value_counts()
plt.pie(count, colors=['green', 'red'], shadow=True, autopct='%1.1f%%')
plt.xlabel('Survived', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data['Gender'], data=data, palette='BrBG')
plt.grid(linestyle='--', axis='y')
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2,1)
sns.countplot(x=data['Helmet_Used'], palette='icefire')
plt.grid(linestyle='--', axis='y')
plt.xlabel('Helmet_Used', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.subplot(1,2,2)
sns.countplot(x=data['Seatbelt_Used'], palette='winter')
plt.grid(linestyle='--', axis='y')
plt.xlabel('Seatbelt_Used', fontsize=12)
plt.ylabel('Count', fontsize=12)

plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data['Gender'],hue=data['Helmet_Used'], data=data, palette='plasma')
plt.grid(linestyle='--', axis='y')
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data['Gender'],hue=data['Seatbelt_Used'], data=data, palette='tab20')
plt.grid(linestyle='--', axis='y')
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data['Gender'],hue=data['Survived'], data=data, palette='tab20_r')
plt.grid(linestyle='--', axis='y')
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=data['Seatbelt_Used'],hue=data['Survived'], data=data, palette='Set1')
plt.grid(linestyle='--', axis='y')
plt.xlabel('Seatbelt_Used', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.subplot(1,2, 1)
sns.histplot(x=data['Age'], kde=True, color='red')
plt.grid(linestyle='--', axis='y')
plt.xlabel('Age', fontsize=12)

plt.subplot(1,2, 2)
sns.histplot(x=data['Speed_of_Impact'], kde=True, color='tomato')
plt.grid(linestyle='--', axis='y')
plt.xlabel('Speed_of_Impact', fontsize=12)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=data['Age'], y=data['Speed_of_Impact'],hue=data['Survived'], s=100,alpha=0.7)
plt.grid(linestyle='--', axis='y')
plt.xlabel('Age', fontsize=12)
plt.ylabel('Speed_of_Impact', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(10,6))
data.boxplot(grid=False)
plt.grid(linestyle='--', axis='y')

# %%
corr = data[['Age', 'Speed_of_Impact', 'Survived']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x=data['Age'], y=data['Speed_of_Impact'],data=data, marker='o')
plt.grid(linestyle='--', axis='y')
plt.xlabel('Age', fontsize=12)
plt.ylabel('Speed_of_Impact', fontsize=12)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Model

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
label_encoder = {}
for col in ['Gender', 'Helmet_Used','Seatbelt_Used']:
    le = LabelEncoder()
    data[col] = le.fit_transform(data[col])
    label_encoder[col] = le

# %%
X = data.iloc[:,:-1]
y = data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (156, 5)
# (156,)
# (40, 5)
# (40,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, confusion_matrix 
lr = LogisticRegression()
lr.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred1 = lr.predict(X_test_scaled)

# %%
print('Accuracy:', accuracy_score(y_test, y_pred1))
print('Precision:', precision_score(y_test, y_pred1))
print(confusion_matrix(y_test, y_pred1))
# Out:
# Accuracy: 0.325
# Precision: 0.4117647058823529
# [[ 6 10]
#  [17  7]]

# %%
tree = DecisionTreeClassifier()
tree.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred2 = tree.predict(X_test_scaled)

# %%
print('Accuracy:', accuracy_score(y_test, y_pred2))
print('Precision:', precision_score(y_test, y_pred2))
print(confusion_matrix(y_test, y_pred2))
# Out:
# Accuracy: 0.4
# Precision: 0.5
# [[ 5 11]
#  [13 11]]

# %%
rf = RandomForestClassifier()
rf.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred3 = rf.predict(X_test_scaled)

# %%
print('Accuracy:', accuracy_score(y_test, y_pred3))
print('Precision:', precision_score(y_test, y_pred3))
print(confusion_matrix(y_test, y_pred3))
# Out:
# Accuracy: 0.425
# Precision: 0.5263157894736842
# [[ 7  9]
#  [14 10]]

# %%
svm = SVC()
svm.fit(X_train_scaled, y_train)
# Out:
# SVC()

# %%
y_pred4 = svm.predict(X_test_scaled)

# %%
print('Accuracy:', accuracy_score(y_test, y_pred4))
print('Precision:', precision_score(y_test, y_pred4))
print(confusion_matrix(y_test, y_pred4))
# Out:
# Accuracy: 0.45
# Precision: 0.5555555555555556
# [[ 8  8]
#  [14 10]]
